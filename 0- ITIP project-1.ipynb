# %%
#  Man I ain't never seen no mustard on that but it might be good my dad might know about it, imma give it to him.
# Aww, mustard! Come on man, now don’t put no mustard on that, you need to put a little season on that thing! WHAT! 
# Man come on get that pepper off there! Come on, somebody come get this man! 
# Come on now, come on get that pepper of there, that’s just too much doggone pepper. I don’t wanna see this no more!
# 󠀀Oh what happened? GAWD!! 🎶🎵 OH MAH GAAAAAAAAD 🎵🎶


winter = {
    {1968: {'Grenoble, France': '0'}},
    {1972: {'Sapporo, Japan': '1'}},
    {1976: {'Innsbruck, Austria': '3'}},
    {1980: {'Lake Placid, United States', '0'}},
    {1984: {'Sarajevo, Bosnia': '1'}},
    {1988: {'Calgary, Alberta': '1'}},
    {1992: {'Albertville, France': '0'}},
    {1994: {'Lillehammer, Norway': '0'}},
    {1998: {'Nagano, Japan': '0'}},
    {2002: {'Salt Lake City, United States': '10'}},
    {2006: {'Turin, Italy': '8'}},
    {2010: {'Vancouver, Canada': '6'}},
    {2014: {'Sochi, Russia': '55'}},
    {2018: {'PyeongChang, South Korea': '4'}}
}


summer = {
    {1968: {'Mexico City, Mexico': '1'}},
    {1972: {'Munich, Germany': '7'}},
    {1976: {'Montreal, Canada': '11'}},
    {1980: {'Moscow, Russia': '0'}},
    {1984: {'Los Angeles, United States': '12'}},
    {1988: {'Seoul, Korea': '10'}},
    {1992: {'Barcelona, Spain': '5'}},
    {1996: {'Atlanta, United States': '7'}},
    {2000: {'Sydney, Australia': '15'}},
    {2004: {'Athens, Greece': '37'}},
    {2008: {'Beijing, China': '91'}},
    {2012: {'London, England': '132'}},
    {2016: {'Rio De Janeiro, Brazil': '16'}}
}


caught_group = {winter, summer}


country = {
    {'Afghanistan': '1'},
    {'Albania': '2'},
    {'Algeria': '1'},
    {'Armenia': '6'},
    {'Australia': '2'},
    {'Austria': '13'},
    {'Azerbaijan': '7'},
    {'Bahrain': '1'},
    {'Belarus': '27'},
    {'Brazil': '5'},
    {'Bulgaria': '10'},
    {'Canada': '1'},
    {'China': '6'},
    {'Colombia': '2'},
    {'Croatia': '1'},
    {'Cuba': '2'},
    {'Cyprus': '1'},
    {'Czechoslovakia': '3'},
    {'England': '2'},
    {'Finland': '1'},
    {'France': '1'},
    {'Georgia': '2'},
    {'Germany': '1'},
    {'Greece': '11'},
    {'Hungary': '7'},
    {'Iceland': '1'},
    {'India': '3'},
    {'Iran': 'None'},
    {'Ireland': '3'},
    {'Italy': '6'},
    {'Jamaica': '1'},
    {'Japan': '3'},
    {'Kazakhstan': '13'},
    {'Kenya': '1'},
    {'Kyrgyzstan': '13'},
    {'Latvia': '1'},
    {'Lebanon': '1'},
    {'Lithuania': '2'},
    {'Moldova': '1'},
    {'Monaco': '1'},
    {'Mongolia': '1'},
    {'Morocco': '3'},
    {'Myanmar': '1'},
    {'Netherlands': '1'},
    {'North Korea': '1'},
    {'Olympic Athletes from Russia': '2'},
    {'Poland': '8'},
    {'Puerto Rico': '2'},
    {'Qatar': '2'},
    {'Romania': '7'},
    {'Russia': '132'},
    {'Saint Kitts and Nevis': '1'},
    {'Saudi Arabia': '2'},
    {'Slovenia': '3'},
    {'Soviet Union': '1'},
    {'Spain': '8'},
    {'Sweden': '5'},
    {'Syria': '1'},
    {'Tajikistan': '1'},
    {'Trinidad and Tobago': '1'},
    {'Turkey', '19'},
    {'Ukraine': '26'},
    {'Unified Team': '1'},
    {'United States': '18'},
    {'Uzbekistan': '1'},
    {'Vietnam': '1'},
    {'West Germany': '1'},

}



drugs = {
    {'Acetazolamide': '3'},
    {'Amphetamine': '3'},
    {'Blood transfusion': '2'},
    {'"Blast Off Red"': '1'},
    {'Caffeine': '1'},
    {'Cannabis': '1'},
    {'Capsaicin': '4'},
    {'Carphedon': '1'},
    {'Cathine': '1'},
    {'CERA': '1'},
    {'Clenbuterol': '6'},
    {'Clenbuterol, Methandienone, and Oxandrolone': '2'},
    {'Codeine, Morphine': '1'},
    {'Coramine': '2'},
    {'Darbepoetin': '3'},
    {'Dehydrochloromethyltestosterone': '1'},
    {'Dianabol': '1'},
    {'Diuretic': '1'},
    {'Drostanolone & Stanozolol': '1'},
    {'Ephedrine': '5'},
    {'Ephedrine and pseudoephedrine': '1'},
    {'EPO': '11'},
    {'EPO and HGH': '1'},
    {'Erythropoietin': '7'},
    {'Ethamivan': '1'},
    {'Ethanol': '1'},
    {'Exogenous testosterone': '2'},
    {'Felbinac': '1'},
    {'Fencamfamine': '1'},
    {'Fenfluramine': '1'},
    {'Fenoterol': '1'},
    {'Furosemide': '13'},
    {'GHRP-2': '1'},
    {'GHRP-2 , Metabolite & Sibutramine': '1'},
    {'GHRP-2 & Metabolite': '3'},
    {'Hydrochlorothiazide': '1'},
    {'Meldonium': '1'},
    {'Mesocarb': '1'},
    {'Metadienone': '1'},
    {'Metandienone & Stanozolol': '1'},
    {'Metenolone & Stanozolol': '2'},
    {'Methamphetamine': '1'},
    {'Methandienone': '5'},
    {'Methenolone': '3'},
    {'Methylhexanamine': '8'},
    {'Methyltestosterone': '1'},
    {'Methyltrienolone': '1'},
    {'Nandrolone': '17'},
    {'Nonivamide': '1'},
    {'Norandrosterone and noretiochdandone', '1'},
    {'Norephedrine': '1'},
    {'Oxandrolone': '6'},
    {'Pemoline': '1'},
    {'Phenylpropanolamine': '1'},
    {'Propanolol': '2'},
    {'Pseudoephedrine': '2'},
    {'Stanozolol': '29'},
    {'Stanozolol & Oxandrolone': '1'},
    {'Stanozolol, Oxandrolone & Turinabol': '1'},
    {'Strychnine': '2'},
    {'Testosterone': '10'},
    {'THG': '1'},
    {'Trimetazidine': '3'},
    {'Tuaminoheptane': '1'},
    {'Turinabol': '65'},
    {'Turinabol & Drostanolone': '1'},
    {'Turinabol & EPO': '1'},
    {'Turinabol & Ipamorelin': '1'},
    {'Turinabol & Metabolite of 1-Testosterone, 1-Androstenedione or 1-Androstenediol': '1'},
    {'Turinabol & Oxandrolone': '1'},
    {'Turinabol & Stanozolol': '23'},
    {'Turinabol & Tamoxifen': '1'},
    {'Turinabol, Metenolone & Stanozolol': '5'}        
}
     
    
drug_horse = {
    {'Antipsychotics (to horse Waterford Crystal)': '1'},
    {'Betamethasone (to horse Goldfever)': '1'},
    
}


drug_offences = {
    {'Administration of prohibited substances': '1'},
    {'BALCO investigation': '3'},
    {'Disappearing Sample': '43'},
    {'Evasion of doping control': '1'},
    {'N/A': '19'},
    {'Possession and use or attempted use of a prohibited substance or method': '1'},
    {'Possession of a prohibited substance or method': '5'},
    {'Possession of blood-transfusion equipment': '2'},
    {'N/A': 'None'},
    {'Refused to submit sample': '2'},
    {'Stimulant': '1'},
    {'Tampering with doping control': '1'},
    {'Use of prohibited substances and methods (self admission)': '1'},
    {'Use, Possession, Trafficking, Administration of Prohibited Substances and Methods and Assisting, Encouraging, Aiding, Abetting, Covering Up': '1'}
}
     
sport_list = {
    {'Alpine Skiing': '1'},
    {'Athletics (Track & Field)': '166'},
    {'Baseball': '2'},
    {'Basketball': '1'},
    {'Biathlon': '15'},
    {'Bobsleigh': '5'},
    {'Boxing': '1'},
    {'Canoeing': '1'},
    {'Cross-Country Skiing', '10'},
    {'Curling', '1'},
    {'Cycling': '12'},
    {'Equestrian': '1'},
    {'Gymnastics': '1'},
    {'Ice Hockey': '17'},
    {'Judo': '1'},
    {'Luge': '2'},
    {'Modern Pentathlon': '4'},
    {'Rowing': '4'},
    {'Sailing': '1'},
    {'Shooting': '2'},
    {'Skeleton': '1'},
    {'Speed Skating': '5'},
    {'Swimming': '4'},
    {'Volleyball': '3'},
    {'Weightlifting': '106'},
    {'Wrestling': '18'}    
}

prohibited_all_time = {
    {'S0': 'Non-Approved Substances'},
    {'S1': 'Anabolic agents'},elated substances, and mimetics'},
    {'S3': 'Beta-2 agonists'},
    {'S4': 'Hormone and metabolic modulators'},
    {'S5': 'Diuretics and masking agents'}    
}
     
prohibited_in_comp = {
    {'S6': 'Stimulants'},
    {'S7': 'Narcotics'},
    {'S8': 'Cannabinoids'},
    {'S9': 'Glucocorticoids'}
}
     
prohibited_part = {
    {'P1': 'Beta-blockers'}    
}     #part stands for particular
     
prohibited_method = {
    {'M1': 'Manipulation of Blood and Blood Components'},
    {'M2': 'Chemical and Physical Manipulation'},
    {'M3': 'Gene and Cell Doping'}
}
    {'S2': 'Peptide hormones, growth factors, r
     

# GRAPH CODE FOR BAR GRAPH HERE OR YOU GET THE WHOOPENING FROM DAD     
     
          
     

    
    
references = ["https://sportsanddrugs.procon.org/doping-cases-at-the-olympics/",
"https://www.wada-ama.org/sites/default/files/resources/files/2021list_en.pdf"]


def parse_command(cmd):
    # parses user input in this function
    parsedCmd = cmd.split(" ") # split "space" allows the user to enter the command, then first argument and second argument (if available)
    
    
    if parsedCmd[0] == 'help':
        print(" ---- Help Section ---- \n\n\n")# list of commands, don't forget to include why there is Olympic Athletes from Russia (OAR/ROC) and Unified Team
    
    elif parsedCmd[0] == 'list': # lists subcategories of lists to print out
        print(" ---- SUBCATEGORIES ---- \n\n\n- Doping Records -\nSeasons/Year\nCountry\nDrugs\nHorses\nOffenses\n\n\n- Prohibited Drugs -\nAll-Time\nIn competition\nParticular Sports\nProhibited Methods")    
     
    elif parsedCmd[0] == 'search': # if statements for different call functions of subcategories, refer to 2nd assignment again
        
     
    else:
        print("Unknown command. Please see help command for a list of commands.")

     


    
def greet(pog): # greet function
    name = input("What is your name?: ")
    return pog + name
print(greet(f'Hello {name}!'))
     

def search_season(caught_group, search):
    return {key:val for key,val in caught_group.items() if any(search in s for s in val)}

def search_drug(drugs, letter):
    return {key:val for key,val in drugs.items() if any(letter in l for l in val)} # returns the search for certain letter(key) and value in drugs dictionary
     
def search_horse(drugs_horse, letter):
    return {key:val for key,val in drugs_horse.items() if any(letter in l for l in val)}

def search_offense(drug_offences, letter):
    return {key:val for key,val in drugs_offences.items() if any(letter in l for l in val)}
     
def search_sport(sport_list, letter):
    return {key:val for key,val in sport_list.items() if any(letter in l for l in val)}
     
def search_country(country, letter):
    return {key:val for key,val in country.items() if any(letter in l for l in val)}

def search_all_time_p(prohibited_all_time, category):
    return {key:val for key,val in prohibited_all_time.items() if any(category in c for c in val)}
 
def search_in_comp(prohibited_in_comp, category):
    return {key:val for key,val in prohibited_in_comp.items() if any(category in c for c in val)}
     
def search_part(prohibited_part, category):
    return {key:val for key,val in prohibited_part.items() if any(category in c for c in val)}
     
def search_method(prohibited_method, category)
    return {key:val for key,val in prohibited_part.items() if any(category in c for c in val)}

def help_call(help_cmd): # list of commands available to use
     print("")
     
     
while(True):
     cmd = input("Please input command or search, see help for command help: ")
         parse_command(cmd) # calls the parse function
             greet()
# Out:
#   File "<ipython-input-4-af1cfca6d53a>", line 301
#     else:
#        ^
# SyntaxError: invalid syntax
